# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from keras.models import load_model
from src.model import SentimentModel
from src.utils import evaluate_model

# Load test data
df_test = pd.read_csv('../data/processed_test.csv')
X_test_texts = df_test['cleaned_text'].values
y_test = df_test['label'].values

# Tokenize and pad
model_handler = SentimentModel()
X_test = model_handler.tokenize_and_pad(X_test_texts)

# Load and evaluate
model = load_model('../models/sentiment_model_best.h5')
evaluate_model(model, X_test, y_test)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.46      0.50      2495
#            1       0.53      0.62      0.57      2505
#
#     accuracy                           0.54      5000
#    macro avg       0.54      0.54      0.54      5000
# weighted avg       0.54      0.54      0.54      5000
